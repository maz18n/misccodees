# %%
##frequentist: Variation fo data & Derived quantities in terms of fixed model parameters
#Bayesians: Variation fo beliefs about parameters in terms of fixed observed data

# %%
import numpy as np

# %%
np.random.seed(2)
e=np.random.normal(300,30,50)
F = np.random.normal(1000,e)

# %%
##Frequentist Approach 
#model: each observation Fi drawn from a Gaussian of widht ei
#build the likelihood multiplying by more datapoints
#basically takes the average of all the values
w= 1./e**2

# %%
e
# Out:
# array([ 287.49726458,  298.31199518,  235.91411713,  349.20812425,
#         246.19693244,  274.74757903,  315.08644251,  262.6413574 ,
#         268.26143343,  272.72977155,  316.54362134,  368.76624038,
#         301.24618179,  266.46223665,  316.17174962,  282.11520901,
#         299.4260851 ,  335.25003659,  277.56387152,  300.27075753,
#         273.6567632 ,  295.30697489,  307.69711356,  270.33662854,
#         289.83534102,  292.91447907,  280.87034963,  264.37163141,
#         257.36348318,  295.39514413,  291.92829119,  366.94100367,
#         226.9569727 ,  303.38179514,  311.1133361 ,  340.78901588,
#         315.0557162 ,  274.67358889,  300.00029284,  316.27057716,
#         290.59475409,  323.13035214,  243.95728036,  351.93553998,
#         344.03034032,  289.92967984,  318.34022339,  301.43911776,
#         275.12594133,  302.63130655])

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\maz'

# %%
import pandas as pd
cars=pd.read_csv('car1.csv')

# %%
cars.columns
# Out:
# Index(['Unnamed: 0', 'vehi_value', 'exposure', 'claim', 'numclaims',
#        'claimcst0', 'veh_body', 'veh_age', 'gender', 'area', 'agecat'],
#       dtype='object')

# %%
cars.loc[:,['claim', 'exposure']]
# Out:
#        claim  exposure
# 0          0  0.303901
# 1          0  0.648871
# 2          0  0.569473
# 3          0  0.317591
# 4          0  0.648871
# 5          0  0.854209
# 6          0  0.854209
# 7          0  0.555784
# 8          0  0.361396
# 9          0  0.520192
# 10         0  0.854209
# 11         0  0.854209
# 12         0  0.492813
# 13         0  0.314853
# 14         1  0.484600
# 15         0  0.391513
# 16         1  0.993840
# 17         1  0.539357
# 18         0  0.451745
# 19         0  0.594114
# 20         0  0.594114
# 21         0  0.536619
# 22         0  0.594114
# 23         0  0.591376
# 24         0  0.999316
# 25         0  0.030116
# 26         0  0.462697
# 27         0  0.317591
# 28         0  0.287474
# 29         0  0.068446
# ...      ...       ...
# 67826      0  0.095825
# 67827      0  0.908966
# 67828      0  0.908966
# 67829      0  0.908966
# 67830      0  0.594114
# 67831      0  0.090349
# 67832      0  0.908966
# 67833      0  0.835044
# ...
